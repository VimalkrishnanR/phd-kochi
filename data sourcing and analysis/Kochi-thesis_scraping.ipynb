# %% [markdown]
# # Scraping workflow notebook

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import io

# %% [markdown]
# # Getting list of Theses titles containing 'Kochi'

# %%
url = "https://shodhganga.inflibnet.ac.in/simple-search?location=&query=Kochi&filter_field_1=title&filter_type_1=contains&filter_value_1=Kochi&filter_field_2=language&filter_type_2=equals&filter_value_2=English&rpp=60&sort_by=score&order=DESC&etal=0&submit_search=Update"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" 
}
print ("time delay for 20 seconds...")
time.sleep(20)

print("Getting 60 titles with Kochi. This will take a while")
response = requests.get(url, headers=headers, timeout = 120)
if response.status_code == 200: 
    data = io.StringIO(response.text)
    table = pd.read_html(data)
#doc = BeautifulSoup(response.text, 'html.parser')
    print("success!")
else: 
    print(f"Status Code: {response.status_code}")
# Out:
# time delay for 20 seconds...
# Getting 60 titles with Kochi. This will take a while
# success!

# %%
type(table)
# Out:
# list

# %%
kochi_title = pd.DataFrame(table[0])

# %%
kochi_title.head()
# Out:
#    Upload Date                                              Title  \
# 0  14-May-2025  Dimensions of Rural Urban Transformation and T...
# 1  14-May-2025  Dimensions of Rural Urban Transformation and T...
# 2  29-Apr-2022  Quantitative distribution of meiobenthos and f...
# 3  12-Mar-2025  Diversity of Actinobacteria in aquatic environ...
# 4   9-Dec-2024  Exploring the right to the city an enquiry int...
#
#              Researcher       Guide(s)
# 0      Arya Lekshmi P T   Lancelet T S
# 1      Arya Lekshmi P T   Lancelet T S
# 2  Chandra Rao, Kovvuru   Annapurna, C
# 3         Das, Vineetha  Joseph, Tom C
# 4               Indu, P    Saji Mathew

# %%
kochi_title.to_csv("kochi_thesis_titles.csv", index = False)

# %% [markdown]
# # Getting list of Theses titles containing 'Cochin'

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import io

# %%
url = "https://shodhganga.inflibnet.ac.in/simple-search?location=%2F&query=&rpp=171&sort_by=score&order=desc&filter_field_1=title&filter_type_1=contains&filter_value_1=Cochin&filter_field_2=language&filter_type_2=equals&filter_value_2=English"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" 
}
print ("time delay for 30 seconds...")
time.sleep(30)

print("Getting 171 titles with Cochin. This will take a while")
response = requests.get(url, headers=headers, timeout = 120)
if response.status_code == 200: 
    data_1 = io.StringIO(response.text)
    #table = pd.read_html(data)
 #doc = BeautifulSoup(response.text, 'html.parser')
    print("success!")
else: 
    print(f"Status Code: {response.status_code}")
# Out:
# time delay for 30 seconds...
# Getting 171 titles with Cochin. This will take a while
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connection.py:759, in HTTPSConnection.connect(self)
#     758 sock: socket.socket | ssl.SSLSocket
# --> 759 self.sock = sock = self._new_conn()
#     760 server_hostname: str = self.host
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except SocketTimeout as e:
# --> 213     raise ConnectTimeoutError(
#     214         self,
#     215         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     216     ) from e
#     218 except OSError as e:
#
# ConnectTimeoutError: (<HTTPSConnection(host='shodhganga.inflibnet.ac.in', port=443) at 0x110a4b750>, 'Connection to shodhganga.inflibnet.ac.in timed out. (connect timeout=120)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File ~/.venvs/lede/lib/python3.13/site-packages/urllib3/util/retry.py:543, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     542     reason = error or ResponseError(cause)
# --> 543     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     545 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='shodhganga.inflibnet.ac.in', port=443): Max retries exceeded with url: /simple-search?location=%2F&query=&rpp=171&sort_by=score&order=desc&filter_field_1=title&filter_type_1=contains&filter_value_1=Cochin&filter_field_2=language&filter_type_2=equals&filter_value_2=English (Caused by ConnectTimeoutError(<HTTPSConnection(host='shodhganga.inflibnet.ac.in', port=443) at 0x110a4b750>, 'Connection to shodhganga.inflibnet.ac.in timed out. (connect timeout=120)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[51], line 9
#       5 print ("time delay for 30 seconds...")
#       6 time.sleep(30)
#       7
#       8 print("Getting 171 titles with Cochin. This will take a while")
# ----> 9 response = requests.get(url, headers=headers, timeout = 120)
#      10 if response.status_code == 200:
#      11     data_1 = io.StringIO(response.text)
#      12     #table = pd.read_html(data)
#
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File ~/.venvs/lede/lib/python3.13/site-packages/requests/adapters.py:717, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     714 if isinstance(e.reason, ConnectTimeoutError):
#     715     # TODO: Remove this in 3.0.0: see #2811
#     716     if not isinstance(e.reason, NewConnectionError):
# --> 717         raise ConnectTimeout(e, request=request)
#     719 if isinstance(e.reason, ResponseError):
#     720     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='shodhganga.inflibnet.ac.in', port=443): Max retries exceeded with url: /simple-search?location=%2F&query=&rpp=171&sort_by=score&order=desc&filter_field_1=title&filter_type_1=contains&filter_value_1=Cochin&filter_field_2=language&filter_type_2=equals&filter_value_2=English (Caused by ConnectTimeoutError(<HTTPSConnection(host='shodhganga.inflibnet.ac.in', port=443) at 0x110a4b750>, 'Connection to shodhganga.inflibnet.ac.in timed out. (connect timeout=120)'))

# %%
table_1 = pd.read_html(data_1)

# %%
table_1
# Out:
# [     Upload Date                                              Title  \
#  0    23-Jun-2015  An Analysis On The Service Quality Of Organise...
#  1    28-Jul-2017            Ecobiology of fouling in Cochin Harbour
#  2    14-Aug-2024  Surviving The Financial Holocaust A Comparativ...
#  3    16-Nov-2018  Prevalence Risk Assessment and Survival Kineti...
#  4    29-Aug-2022  Sedimentary Heavy Metals as Signatures of Anth...
#  ..           ...                                                ...
#  166  12-Jun-2014  Spatial and temporal variation of phytoplankto...
#  167  15-Nov-2012  Studies on Venom of the fish Scatophagus Argus...
#  168  27-Dec-2012  Meteorological aspects of the environment of C...
#  169  11-Apr-2013  Spatial and temporal variation of microbial co...
#  170  17-May-2013  Synergic Reactions in the Estuarine Environmen...
#
#           Researcher               Guide(s)
#  0     Harish K Nair         Dr. M. Ganesan
#  1     Meenakumari B    Balakrishnan Nair N
#  2         Sunil Lal               Pratheep
#  3    Ally C. Antony      Mohamed Hatha A A
#  4       Jose Mathew           Anu Gopinath
#  ..              ...                    ...
#  166    Haridevi C K         Revichandran C
#  167    Sivan, Gisha      Radhakrishnan C K
#  168         Bindu G         Anil Kumar K G
#  169  Joseph, Neetha  Achuthankutty, Shanta
#  170     Sanjana M C           Balchand A N
#
#  [171 rows x 4 columns]]

# %%
type(table_1)
# Out:
# list

# %%
cochin_title = pd.DataFrame(table_1[0])

# %%
cochin_title.shape
# Out:
# (171, 4)

# %%
cochin_title.to_csv("cochin_thesis_titles.csv", index = False)

# %% [markdown]
# # Getting list of Theses titles containing 'Ernakulam'

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import io

# %%
url = "https://shodhganga.inflibnet.ac.in/simple-search?query=Ernakulam&sort_by=score&order=asc&rpp=120&filter_field_1=title&filter_type_1=contains&filter_value_1=Ernakulam&etal=0&filtername=language&filterquery=English&filtertype=equals"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" 
}
print ("time delay for 30 seconds...")
time.sleep(30)

print("Getting 120 titles with Ernakulam. This will take a while")
response = requests.get(url, headers = headers, timeout = 180)
if response.status_code == 200: 
    data_2 = io.StringIO(response.text)
    #table = pd.read_html(data)
 #doc = BeautifulSoup(response.text, 'html.parser')
    print("success!")
else: 
    print(f"Status Code: {response.status_code}")
# Out:
# time delay for 30 seconds...
# Getting 120 titles with Ernakulam. This will take a while
# success!

# %%
table_2 = pd.read_html(data_2)

# %%
table_2
# Out:
# [     Upload Date                                              Title  \
#  0    19-Dec-2017  Pollution stress responses in fishes of Periya...
#  1     4-Jan-2016  Study of occupational aspirations of college s...
#  2    25-Apr-2014  Women entrepreneurs in Ernakulam district Kera...
#  3    18-Jun-2019  A Study on Depression Anxiety and Stress among...
#  4    14-Aug-2017  Customer Perceptions towards Service Quality o...
#  ..           ...                                                ...
#  115  23-Mar-2018  Ichthyo diversity of Puthenvelikkara and its e...
#  116   3-Jul-2023  Financial Performance of Urban Cooperative Ban...
#  117  20-May-2024  Present status of fish eating birds in pokkali...
#  118  24-Oct-2024  An evaluative study of the lead bank scheme in...
#  119  26-Nov-2024  An evaluative study on the effectiveness of fi...
#
#              Researcher               Guide(s)
#  0        Asha Raj, K R            Joseph, M L
#  1        Varghese, K V    Payyappilly, Jose T
#  2      Susan Thomas, P           Kamalamma, N
#  3    Shincy Francis M.             Nirmala D.
#  4       Ameena Babu. V              Amudha. R
#  ..                 ...                    ...
#  115         Shyla, M H           Jameela, K S
#  116        Shabu, K.R.            Manivel, S.
#  117      Surya Babu, S         Raju Thomas, K
#  118        Gibin Jacob        Rajagopala Nair
#  119           Bilu Job  Sybila Pius Fernandez
#
#  [120 rows x 4 columns]]

# %%
ernakulam_title = pd.DataFrame(table_2[0])

# %%
ernakulam_title.shape
# Out:
# (120, 4)

# %%
ernakulam_title.to_csv("ernakulam_thesis_titles.csv", index = False)
